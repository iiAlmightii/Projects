# %%
import pandas as pd
import os

# %%
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in c:\users\chans\anaconda3\lib\site-packages (3.5.0)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (3.5.2)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (4.64.1)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (0.12.3)
# Requirement already satisfied: multimethod<1.10,>=1.4 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (1.9)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (1.21.5)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (2.13.3)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (1.4.4)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (1.9.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (2.11.3)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (1.10.2)
# Requirement already satisfied: requests<2.29,>=2.24.0 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (2.28.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (0.11.2)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\chans\anaconda3\lib\site-packages (from pandas-profiling) (0.7.5)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\chans\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (21.4.0)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\chans\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (0.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\chans\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (2.8.4)
# Requirement already satisfied: Pillow in c:\users\chans\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (9.2.0)
# Requirement already satisfied: imagehash in c:\users\chans\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (4.3.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\chans\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->pandas-profiling) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\chans\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\chans\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\chans\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\chans\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chans\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chans\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chans\anaconda3\lib\site-packages (from pandas!=1.4.0,<1.6,>1.1->pandas-profiling) (2022.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\chans\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->pandas-profiling) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\chans\anaconda3\lib\site-packages (from pydantic<1.11,>=1.8.1->pandas-profiling) (4.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chans\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\chans\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chans\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chans\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (1.26.11)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\chans\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->pandas-profiling) (0.5.2)
# Requirement already satisfied: colorama in c:\users\chans\anaconda3\lib\site-packages (from tqdm<4.65,>=4.48.2->pandas-profiling) (0.4.5)
# Requirement already satisfied: six in c:\users\chans\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\chans\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->pandas-profiling) (1.3.0)

# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %%
df = pd.read_excel(r'MARch_Punjab BB_Raw_Baseline Export_12Dec2022.xlsx')
print(df)
# Out:
#       Response ID         Time Started       Date Submitted    Status  \
# 0              46  2022-04-11 07:03:00  2022-04-11 07:07:00  Complete
# 1              47  2022-04-11 13:18:00  2022-04-11 13:18:00   Partial
# 2              48  2022-04-11 15:33:00  2022-04-11 15:45:00  Complete
# 3              49  2022-04-11 15:44:00  2022-04-11 15:56:00  Complete
# 4              50  2022-04-11 15:46:00  2022-04-11 16:06:00  Complete
# ...           ...                  ...                  ...       ...
# 9243         9291  28/11/2022 13:48:48  28/11/2022 13:50:43   Partial
# 9244         9292  28/11/2022 13:57:28  28/11/2022 14:01:56  Complete
# 9245         9293  28/11/2022 14:43:04  28/11/2022 14:45:36  Complete
# 9246         9294  28/11/2022 15:02:49  28/11/2022 15:12:42  Complete
# 9247         9295  28/11/2022 18:40:27  28/11/2022 18:53:50  Complete
#
#       Contact ID  Legacy Comments  Comments Language  \
# 0            NaN              NaN       NaN    Hindi
# 1            NaN              NaN       NaN  English
# 2            NaN              NaN       NaN    Hindi
# 3            NaN              NaN       NaN    Hindi
# 4            NaN              NaN       NaN    Hindi
# ...          ...              ...       ...      ...
# 9243         NaN              NaN       NaN    Hindi
# 9244         NaN              NaN       NaN    Hindi
# 9245         NaN              NaN       NaN    Hindi
# 9246         NaN              NaN       NaN    Hindi
# 9247         NaN              NaN       NaN    Hindi
#
#                                                 Referer  \
# 0                              android-app://com.slack/
# 1                               https://www.google.com/
# 2     https://survey.alchemer.com/s3/7079461/PunjabB...
# 3     https://survey.alchemer.com/s3/7079461/PunjabB...
# 4     https://survey.alchemer.com/s3/7079461/PunjabB...
# ...                                                 ...
# 9243  https://survey.alchemer.com/s3/7079461/PunjabB...
# 9244  https://survey.alchemer.com/s3/7079461/PunjabB...
# 9245  https://survey.alchemer.com/s3/7079461/PunjabB...
# 9246  https://survey.alchemer.com/s3/7079461/PunjabB...
# 9247  https://survey.alchemer.com/s3/7079461/PunjabB...
#
#                                SessionID  ...  \
# 0     1667525585_63646bd1608ee8.05172050  ...
# 1     1667548123_6364c3db5b3093.97723775  ...
# 2     1667556201_6364e369bc4343.61409321  ...
# 3     1667556813_6364e5cdd819a0.65404518  ...
# 4     1667556953_6364e6595cdb53.83737631  ...
# ...                                  ...  ...
# 9243  1669623522_63846ee2a2ad51.42937627  ...
# 9244  1669624038_638470e65adb26.00778922  ...
# 9245  1669626776_63847b984bc069.01579430  ...
# 9246  1669627952_63848030838a94.91203939  ...
# 9247  1669641022_6384b33e983a23.32849690  ...
#
#                     17a_ind_againstnorm  \
# 0                         (d) ???? / no
# 1                                   NaN
# 2                         (d) ???? / no
# 3     (a) ???, ?? ??? / yes, many times
# 4                         (d) ???? / no
# ...                                 ...
# 9243                                NaN
# 9244  (a) ???, ?? ??? / yes, many times
# 9245  (b) ???, ??? ??? / yes, sometimes
# 9246  (a) ???, ?? ??? / yes, many times
# 9247                      (d) ???? / no
#
#                                     17b_ind_againstnorm  \
# 0     (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                   NaN
# 2             (b) ??? ???? ??????? ?? / Did not want to
# 3                                                   NaN
# 4             (b) ??? ???? ??????? ?? / Did not want to
# ...                                                 ...
# 9243                                                NaN
# 9244                                                NaN
# 9245                                                NaN
# 9246                                                NaN
# 9247          (b) ??? ???? ??????? ?? / Did not want to
#
#                                 18a_ind_reflection  \
# 0                                    (d) ???? / no
# 1                                              NaN
# 2     (c) ???, ??? ??? ?? ??? / yes, once or twice
# 3     (c) ???, ??? ??? ?? ??? / yes, once or twice
# 4                (a) ???, ?? ??? / yes, many times
# ...                                            ...
# 9243                                           NaN
# 9244             (a) ???, ?? ??? / yes, many times
# 9245             (a) ???, ?? ??? / yes, many times
# 9246                                 (d) ???? / no
# 9247                                 (d) ???? / no
#
#                                      18b_ind_reflection  \
# 0     (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9243                                                NaN
# 9244                                                NaN
# 9245                                                NaN
# 9246  (c) ??? ???? ???????/??????? ??, ?? ???? ???? ...
# 9247                  (a) ??? ???? ?? / Did not need to
#
#                                19a_ind_questioning  \
# 0                                    (d) ???? / no
# 1                                              NaN
# 2                (b) ???, ??? ??? / yes, sometimes
# 3                (b) ???, ??? ??? / yes, sometimes
# 4                (a) ???, ?? ??? / yes, many times
# ...                                            ...
# 9243                                           NaN
# 9244                                 (d) ???? / no
# 9245             (b) ???, ??? ??? / yes, sometimes
# 9246  (c) ???, ??? ??? ?? ??? / yes, once or twice
# 9247             (a) ???, ?? ??? / yes, many times
#
#                                     19b_ind_questioning  \
# 0     (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9243                                                NaN
# 9244                  (a) ??? ???? ?? / Did not need to
# 9245                                                NaN
# 9246                                                NaN
# 9247                                                NaN
#
#                20a_ind_informeddecision  \
# 0                         (d) ???? / no
# 1                                   NaN
# 2     (a) ???, ?? ??? / yes, many times
# 3     (a) ???, ?? ??? / yes, many times
# 4     (a) ???, ?? ??? / yes, many times
# ...                                 ...
# 9243                                NaN
# 9244  (a) ???, ?? ??? / yes, many times
# 9245  (a) ???, ?? ??? / yes, many times
# 9246  (b) ???, ??? ??? / yes, sometimes
# 9247  (b) ???, ??? ??? / yes, sometimes
#
#                                20b_ind_informeddecision  survey_duration  \
# 0     (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...            168.0
# 1                                                   NaN              NaN
# 2                                                   NaN            480.0
# 3                                                   NaN            553.0
# 4                                                   NaN            948.0
# ...                                                 ...              ...
# 9243                                                NaN              NaN
# 9244                                                NaN            212.0
# 9245                                                NaN             69.0
# 9246                                                NaN            500.0
# 9247                                                NaN            702.0
#
#                                            open_comment
# 0                                                    Oo
# 1                                                   NaN
# 2                                                   No
# 3     I have Some Experience of Digital Marketing, V...
# 4                                                   NaN
# ...                                                 ...
# 9243                                                NaN
# 9244                                                NaN
# 9245                                                NaN
# 9246                                                NaN
# 9247                                                NaN
#
# [9248 rows x 73 columns]

# %%
df.head()
# Out:
#    Response ID    Status Language Country         City State/Region  \
# 0           46  Complete    Hindi   India       Mumbai           16
# 1           47   Partial  English   India     Ludhiana           23
# 2           48  Complete    Hindi   India  Kurukshetra           10
# 3           49  Complete    Hindi   India     Ludhiana           23
# 4           50  Complete    Hindi   India     Ludhiana           23
#
#                name  dob_year  Unnamed: 22   dob_month hh_size  \
# 0             Nsshh    2005.0          NaN        June       2
# 1               NaN       NaN          NaN         NaN     NaN
# 2            Saloni    2007.0          NaN   September       5
# 3  Akarshit Bhateja    2006.0          NaN      August       4
# 4       Lalit kumar    2008.0          NaN       March       4
#
#                                    mother_education  \
# 0                    ??? ?????? ???? / No education
# 1                                               NaN
# 2   9??? ???? ??? ?? ??? ??? / 9th standard or less
# 3  10??? ??? / ??????? / 10th pass or matriculation
# 4  10??? ??? / ??????? / 10th pass or matriculation
#
#                                    father_education personal_phone epunjab_ID  \
# 0                    ??? ?????? ???? / No education      ??? / Yes        NaN
# 1                                               NaN            NaN        NaN
# 2   9??? ???? ??? ?? ??? ??? / 9th standard or less      ???? / No        NaN
# 3                             12??? ??? / 12th pass      ??? / Yes        NaN
# 4  10??? ??? / ??????? / 10th pass or matriculation      ???? / No        NaN
#
#    demographic_duration                           1a_grit_localtravel  \
# 0                  48.0                                (d) ????  / no
# 1                   NaN                                           NaN
# 2                 239.0        (b) ???, ???, ??? ??? / yes, sometimes
# 3                 203.0             (a) ???, ?? ??? / yes, many times
# 4                 284.0  (c) ???, ??? ??? ?? ??? / yes, once or twice
#
#                                  1b_grit_localtravel  \
# 0  (c) ??? ???? ???????/??????? ??, ?? ???? ???? ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 2a_grit_errands  \
# 0                                 (d) ???? / no
# 1                                           NaN
# 2             (a) ???, ?? ??? / yes, many times
# 3             (a) ???, ?? ??? / yes, many times
# 4  (c) ???, ??? ??? ?? ??? / yes, once or twice
#
#                                      2b_grit_errands  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#               3a_grit_publicspeaking  \
# 0                      (d) ???? / no
# 1                                NaN
# 2  (a) ???, ?? ??? / yes, many times
# 3                      (d) ???? / no
# 4                      (d) ???? / no
#
#                               3b_grit_publicspeaking  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3          (b) ??? ???? ??????? ?? / Did not want to
# 4                  (a) ??? ???? ?? / Did not need to
#
#                       4a_grit_discussion  \
# 0                          (d) ???? / no
# 1                                    NaN
# 2                          (d) ???? / no
# 3  (b) ???,???, ??? ??? / yes, sometimes
# 4  (b) ???,???, ??? ??? / yes, sometimes
#
#                                   4b_grit_discussion  \
# 0  (c) ??? ???? ???????/??????? ??, ?? ???? ???? ...
# 1                                                NaN
# 2                  (a) ??? ???? ?? / Did not need to
# 3                                                NaN
# 4                                                NaN
#
#                              5a_grit_persevered  \
# 0                                 (d) ???? / no
# 1                                           NaN
# 2  (c) ???, ??? ??? ?? ??? / yes, once or twice
# 3             (a) ???, ?? ??? / yes, many times
# 4         (b) ???,???, ??? ??? / yes, sometimes
#
#                                   5b_grit_persevered  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#               6a_tnt_extraleadership  \
# 0                      (d) ???? / no
# 1                                NaN
# 2  (a) ???, ?? ??? / yes, many times
# 3  (b) ???, ??? ??? / yes, sometimes
# 4  (a) ???, ?? ??? / yes, many times
#
#                               6b_tnt_extraleadership  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 7a_tnt_newskill  \
# 0                                 (d) ???? / no
# 1                                           NaN
# 2  (c) ???, ??? ??? ?? ??? / yes, once or twice
# 3             (a) ???, ?? ??? / yes, many times
# 4             (b) ???, ??? ??? / yes, sometimes
#
#                                      7b_tnt_newskill  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                 8a_tnt_helpingothers  \
# 0                      (d) ???? / no
# 1                                NaN
# 2  (a) ???, ?? ??? / yes, many times
# 3                      (d) ???? / no
# 4  (a) ???, ?? ??? / yes, many times
#
#                                 8b_tnt_helpingothers  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3          (b) ??? ???? ??????? ?? / Did not want to
# 4                                                NaN
#
#                               9a_tnt_risktaking  \
# 0                                 (d) ???? / no
# 1                                           NaN
# 2  (c) ???, ??? ??? ?? ??? / yes, once or twice
# 3  (c) ???, ??? ??? ?? ??? / yes, once or twice
# 4             (a) ???, ?? ??? / yes, many times
#
#                                    9b_tnt_risktaking 10a_tnt_project  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...  (b) ????  / no
# 1                                                NaN             NaN
# 2                                                NaN  (b) ????  / no
# 3                                                NaN  (b) ????  / no
# 4                                                NaN   (a) ??? / yes
#
#   10a_tnt_project_example                                    10b_tnt_project  \
# 0                     NaN  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                     NaN                                                NaN
# 2                     NaN  (c) ??? ???? ???????/??????? ??, ?? ???? ???? ...
# 3                     NaN  (c) ??? ???? ???????/??????? ??, ?? ???? ???? ...
# 4                     NaN                                                NaN
#
#                                 11a_sa_feedback  \
# 0                                 (d) ???? / no
# 1                                           NaN
# 2             (b) ???, ??? ??? / yes, sometimes
# 3  (c) ???, ??? ??? ?? ??? / yes, once or twice
# 4             (b) ???, ??? ??? / yes, sometimes
#
#                                      11b_sa_feedback  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                              12a_sa_helpseeking  \
# 0                                 (d) ???? / no
# 1                                           NaN
# 2  (c) ???, ??? ??? ?? ??? / yes, once or twice
# 3                                 (d) ???? / no
# 4             (b) ???, ??? ??? / yes, sometimes
#
#                                   12b_sa_helpseeking  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3          (b) ??? ???? ??????? ?? / Did not want to
# 4                                                NaN
#
#                        13a_sa_values  \
# 0                      (d) ???? / no
# 1                                NaN
# 2  (a) ???, ?? ??? / yes, many times
# 3  (b) ???, ??? ??? / yes, sometimes
# 4  (a) ???, ?? ??? / yes, many times
#
#                                        13b_sa_values  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      14a_sa_emotions  \
# 0                      (d) ???? / no
# 1                                NaN
# 2  (a) ???, ?? ??? / yes, many times
# 3  (a) ???, ?? ??? / yes, many times
# 4                      (d) ???? / no
#
#                                      14b_sa_emotions  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  (c) ??? ???? ???????/??????? ??, ?? ???? ???? ...
#
#                                15a_sa_influence  \
# 0                                 (d) ???? / no
# 1                                           NaN
# 2  (c) ???, ??? ??? ?? ??? / yes, once or twice
# 3             (b) ???, ??? ??? / yes, sometimes
# 4                                 (d) ???? / no
#
#                                     15b_sa_influence  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4          (b) ??? ???? ??????? ?? / Did not want to
#
#             16a_ind_doingthingsalone  \
# 0                      (d) ???? / no
# 1                                NaN
# 2  (a) ???, ?? ??? / yes, many times
# 3  (a) ???, ?? ??? / yes, many times
# 4  (a) ???, ?? ??? / yes, many times
#
#                              16b_sa_doingthingsalone  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  17a_ind_againstnorm  \
# 0                      (d) ???? / no
# 1                                NaN
# 2                      (d) ???? / no
# 3  (a) ???, ?? ??? / yes, many times
# 4                      (d) ???? / no
#
#                                  17b_ind_againstnorm  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2          (b) ??? ???? ??????? ?? / Did not want to
# 3                                                NaN
# 4          (b) ??? ???? ??????? ?? / Did not want to
#
#                              18a_ind_reflection  \
# 0                                 (d) ???? / no
# 1                                           NaN
# 2  (c) ???, ??? ??? ?? ??? / yes, once or twice
# 3  (c) ???, ??? ??? ?? ??? / yes, once or twice
# 4             (a) ???, ?? ??? / yes, many times
#
#                                   18b_ind_reflection  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  19a_ind_questioning  \
# 0                      (d) ???? / no
# 1                                NaN
# 2  (b) ???, ??? ??? / yes, sometimes
# 3  (b) ???, ??? ??? / yes, sometimes
# 4  (a) ???, ?? ??? / yes, many times
#
#                                  19b_ind_questioning  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#             20a_ind_informeddecision  \
# 0                      (d) ???? / no
# 1                                NaN
# 2  (a) ???, ?? ??? / yes, many times
# 3  (a) ???, ?? ??? / yes, many times
# 4  (a) ???, ?? ??? / yes, many times
#
#                             20b_ind_informeddecision  \
# 0  (d) ???? ???? ?? (?????? / ?????? ??? ???? / ?...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         open_comment
# 0                                                 Oo
# 1                                                NaN
# 2                                                No
# 3  I have Some Experience of Digital Marketing, V...
# 4                                                NaN

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
columns = ['Postal', 'Latitude','Longitude','IP Address','survey_duration','New Hidden Value']
df.drop(columns, inplace=True, axis=1)

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\chans\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\chans\anaconda3\lib\site-packages (from plotly) (8.0.1)

# %%
import plotly.express as px
import chart_studio.plotly as py
import plotly.graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13840\2851084994.py in <module>
#       1 import plotly.express as px
# ----> 2 import chart_studio.plotly as py
#       3 import plotly.graph_objects as go
#
# ModuleNotFoundError: No module named 'chart_studio'

# %%
data = [go.Bar(x=df.School,
            y=df.Gap)]

py.iplot(data, filename='jupyter-basic_bar')
