# %%
import pandas as pd
import os

# %%
var1 = pd.read_excel("CHANDAN_MARch Punjab BB_Raw Baseline Export_12Dec2022.xlsx",  sheet_name=0)

# %%
df = pd.DataFrame(var1)

# %%
df
# Out:
#       Response_ID        Time_Started      Date_Submitted    Status  \
# 0              46 2022-11-04 07:03:28 2022-11-04 07:07:04  Complete
# 1              47 2022-11-04 13:18:48 2022-11-04 13:18:48   Partial
# 2              48 2022-11-04 15:33:34 2022-11-04 15:45:33  Complete
# 3              49 2022-11-04 15:44:03 2022-11-04 15:56:39  Complete
# 4              50 2022-11-04 15:46:08 2022-11-04 16:06:40  Complete
# ...           ...                 ...                 ...       ...
# 9243         9291 2022-11-28 13:48:48 2022-11-28 13:50:43   Partial
# 9244         9292 2022-11-28 13:57:28 2022-11-28 14:01:56  Complete
# 9245         9293 2022-11-28 14:43:04 2022-11-28 14:45:36  Complete
# 9246         9294 2022-11-28 15:02:49 2022-11-28 15:12:42  Complete
# 9247         9295 2022-11-28 18:40:27 2022-11-28 18:53:50  Complete
#
#       Contact_ID  Legacy_Comments  Comments Language  \
# 0            NaN              NaN       NaN    Hindi
# ...

# %%
a = var1.dropna(subset = "Student_ID")
len(a)
# Out:
# 6615

# %%
df.columns
# Out:
# Index(['Response_ID', 'Time_Started', 'Date_Submitted', 'Status', 'Contact_ID',
#        'Legacy_Comments', 'Comments', 'Language', 'Referer', 'SessionID',
#        'User_Agent', 'Tags', 'IP_Address', 'Longitude', 'Latitude', 'Country',
#        'City', 'State/Region', 'Postal', 'New_Hidden_Value', 'name',
#        'dob_year', 'dob_month', 'dob_date', 'hh_size', 'mother_education',
#        'father_education', 'personal_phone', 'Student_ID',
#        'demographic_duration', '1a_grit_localtravel', '1b_grit_localtravel',
#        '2a_grit_errands', '2b_grit_errands', '3a_grit_publicspeaking',
#        '3b_grit_publicspeaking', '4a_grit_discussion', '4b_grit_discussion',
#        '5a_grit_persevered', '5b_grit_persevered', '6a_tnt_extraleadership',
#        '6b_tnt_extraleadership', '7a_tnt_newskill', '7b_tnt_newskill',
#        '8a_tnt_helpingothers', '8b_tnt_helpingothers', '9a_tnt_risktaking',
#        '9b_tnt_risktaking', '10a_tnt_project', '10a_tnt_project_example',
# ...

# %%
a.duplicated(subset = ["Student_ID" ,"name",'1a_grit_localtravel', '1b_grit_localtravel',
       '2a_grit_errands', '2b_grit_errands', '3a_grit_publicspeaking',
       '3b_grit_publicspeaking', '4a_grit_discussion', '4b_grit_discussion',
       '5a_grit_persevered', '5b_grit_persevered', '6a_tnt_extraleadership',
       '6b_tnt_extraleadership', '7a_tnt_newskill', '7b_tnt_newskill',
       '8a_tnt_helpingothers', '8b_tnt_helpingothers', '9a_tnt_risktaking',
       '9b_tnt_risktaking', '10a_tnt_project', '10a_tnt_project_example',
       '10b_tnt_project', '11a_sa_feedback', '11b_sa_feedback',
       '12a_sa_helpseeking', '12b_sa_helpseeking', '13a_sa_values',
       '13b_sa_values', '14a_sa_emotions', '14b_sa_emotions',
       '15a_sa_influence', '15b_sa_influence', '16a_ind_doingthingsalone',
       '16b_sa_doingthingsalone', '17a_ind_againstnorm', '17b_ind_againstnorm',
       '18a_ind_reflection', '18b_ind_reflection', '19a_ind_questioning',
       '19b_ind_questioning', '20a_ind_informeddecision']).sum()
# Out:
# 166

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.groupby(['Student_ID', 'name']).filter(lambda group: len(group) > 1).groupby(['Student_ID', 'name']).size()
# Out:
# Student_ID          name
# 6                   Sanjana           2
# 7                   Mehakdeep kaur    4
# 15533               ANMOL Singh       2
# 16982               Mahedil aara      2
# 30689               Mehak bano        2
#                                      ..
# INTRO               Sapna             2
#                     ਨਵਦੀਪ ਕੌਰ         2
# Intro               Jasmine sidhu     2
# Om781444@gmail.com  Omparkash Ram     2
# intro               Varun kashyap     2
# Length: 1180, dtype: int64

# %%
a.groupby(['Student_ID', 'name']).filter(lambda group: len(group) > 1).groupby(['Student_ID', 'name']).size()
# Out:
# Student_ID          name
# 6                   Sanjana           2
# 7                   Mehakdeep kaur    4
# 15533               ANMOL Singh       2
# 16982               Mahedil aara      2
# 30689               Mehak bano        2
#                                      ..
# INTRO               Sapna             2
#                     ਨਵਦੀਪ ਕੌਰ         2
# Intro               Jasmine sidhu     2
# Om781444@gmail.com  Omparkash Ram     2
# intro               Varun kashyap     2
# Length: 1180, dtype: int64

# %%
len(a.Student_ID.unique())
# Out:
# 4638

# %%
epunjab=df.loc[:,"Student_ID_(ePunjab ID)"]

# %%
print(epunjab.duplicated())
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
# 30       True
# 31       True
# 32       True
# 33       True
# 34       True
# 35       True
# 36       True
# 37       True
# 38       True
# 39       True
# 40       True
# 41       True
# 42       True
# 43       True
# 44       True
# 45       True
# 46       True
# 47       True
# 48       True
# 49       True
# 50       True
# 51       True
# 52       True
# 53       True
# 54       True
# 55       True
# 56       True
# 57       True
# 58       True
# 59       True
# 60       True
# 61       True
# ...

# %%
print(var1[var1.duplicated()])
# Out:
# Empty DataFrame
# ...

# %%
print(len(df.duplicated(subset='Student_ID_(ePunjab ID)'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13936\2110238220.py in <module>
# ----> 1 print(len(df.duplicated(subset='Student_ID_(ePunjab ID)'.notna())))
#
# AttributeError: 'str' object has no attribute 'notna'

# %%
print((df.duplicated(subset='Student_ID_(ePunjab ID)')))
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
# 30       True
# 31       True
# 32       True
# 33       True
# 34       True
# 35       True
# 36       True
# 37       True
# 38       True
# 39       True
# 40       True
# 41       True
# 42       True
# 43       True
# 44       True
# 45       True
# 46       True
# 47       True
# 48       True
# 49       True
# 50       True
# 51       True
# 52       True
# 53       True
# 54       True
# 55       True
# 56       True
# 57       True
# 58       True
# 59       True
# 60       True
# 61       True
# ...

# %%
df["Student_ID"].duplicated().sum()
# Out:
# 4609

# %%
df.duplicated(keep = False).sum()
# Out:
# 0

# %%
df.pivot_table(index=['Student_ID','name',], aggfunc='size')
# Out:
# Student_ID          name
# 0                   Damanpreet singh                                                   1
#                     Rajat chauhan                                                      1
# 2                   Kashish                                                            1
# 4                   Ritika                                                             1
# 6                   Anjan                                                              1
#                     Sanjana                                                            2
# 7                   Mehakdeep kaur                                                     4
# 58                  Shivam                                                             1
# 77                  Lovepreet singh                                                    1
# 92                  Arshdeep singh                                                     1
# ...

# %%
df1 = pd.read_excel("CHANDAN_MARch Punjab BB_Raw Baseline Export_12Dec2022.xlsx",  sheet_name=1)
df1.head()
# Out:
#    Student_ID       Student_Name  Gender  Class Section      Stream  \
# 0     1992014        SIMRAN KAUR  Female     12       F  Vocational
# 1     2270370       SACHIN KUMAR    Male     12       N    Commerce
# 2     2351011  SIMRAN DEEP SINGH    Male     12       H  Vocational
# 3     2614447    PALVINDER SINGH    Male     11       C        Arts
# 4     2614551             SHIVAM    Male     11       E    Commerce
#
#    UDISE_Code                                        School_Name   School_Id
# 0  3090508902                                       GMSSS P.A.U.  3090508902
# 1  3090508902                                       GMSSS P.A.U.  3090508902
# 2  3090508902                                       GMSSS P.A.U.  3090508902
# 3  3040111410  FREEDOM FIGHTER SH. AJIT SAINI GMSSS CO-ED LAD...  3040111410
# 4  3040111410  FREEDOM FIGHTER SH. AJIT SAINI GMSSS CO-ED LAD...  3040111410

# %%
df_merge = pd.merge(df, df1, on='Student_ID')

# %%
df_merge.to_excel("March_baseline_merged_by_gender.xlsx")

# %%
df_merge.shape
# Out:
# (6219, 81)

# %%
df.head()
# Out:
#    Response_ID        Time_Started      Date_Submitted    Status  Contact_ID  \
# 0           46 2022-11-04 07:03:28 2022-11-04 07:07:04  Complete         NaN
# 1           47 2022-11-04 13:18:48 2022-11-04 13:18:48   Partial         NaN
# 2           48 2022-11-04 15:33:34 2022-11-04 15:45:33  Complete         NaN
# 3           49 2022-11-04 15:44:03 2022-11-04 15:56:39  Complete         NaN
# 4           50 2022-11-04 15:46:08 2022-11-04 16:06:40  Complete         NaN
#
#    Legacy_Comments  Comments Language  \
# 0              NaN       NaN    Hindi
# 1              NaN       NaN  English
# 2              NaN       NaN    Hindi
# 3              NaN       NaN    Hindi
# 4              NaN       NaN    Hindi
#
#                                              Referer  \
# 0                           android-app://com.slack/
# 1                            https://www.google.com/
# 2  https://survey.alchemer.com/s3/7079461/PunjabB...
# ...

# %%
df.isnull().sum()
# Out:
# Response_ID                    0
# Time_Started                   0
# Date_Submitted                 0
# Status                         0
# Contact_ID                  9248
# Legacy_Comments             9248
# Comments                    9248
# Language                       0
# Referer                        0
# SessionID                      0
# User_Agent                     0
# Tags                        9248
# IP_Address                     0
# Longitude                     18
# Latitude                      18
# Country                       18
# City                         879
# State/Region                 823
# Postal                       882
# New_Hidden_Value            2155
# name                        2322
# dob_year                    2369
# dob_month                   2374
# dob_date                    2377
# hh_size                     2349
# mother_education            2354
# father_education            2358
# personal_phone              2359
# ...

# %%
df.isnull().sum()
# Out:
# Response_ID                    0
# Time_Started                   0
# Date_Submitted                 0
# Status                         0
# Contact_ID                  9248
# Legacy_Comments             9248
# Comments                    9248
# Language                       0
# Referer                        0
# SessionID                      0
# User_Agent                     0
# Tags                        9248
# IP_Address                     0
# Longitude                     18
# Latitude                      18
# Country                       18
# City                         879
# State/Region                 823
# Postal                       882
# New_Hidden_Value            2155
# name                        2322
# dob_year                    2369
# dob_month                   2374
# dob_date                    2377
# hh_size                     2349
# mother_education            2354
# father_education            2358
# personal_phone              2359
# ...

# %%
# Out:
# False    9248
# dtype: int64

# %%
# Out:
# 9248

# %%
myvar = pd.DataFrame(df)

# %%
myvar.drop_duplicates()
# Out:
#       Response ID        Time Started      Date Submitted    Status  \
# 0              46 2022-11-04 07:03:28 2022-11-04 07:07:04  Complete
# 1              47 2022-11-04 13:18:48 2022-11-04 13:18:48   Partial
# 2              48 2022-11-04 15:33:34 2022-11-04 15:45:33  Complete
# 3              49 2022-11-04 15:44:03 2022-11-04 15:56:39  Complete
# 4              50 2022-11-04 15:46:08 2022-11-04 16:06:40  Complete
# ...           ...                 ...                 ...       ...
# 9243         9291 2022-11-28 13:48:48 2022-11-28 13:50:43   Partial
# 9244         9292 2022-11-28 13:57:28 2022-11-28 14:01:56  Complete
# 9245         9293 2022-11-28 14:43:04 2022-11-28 14:45:36  Complete
# 9246         9294 2022-11-28 15:02:49 2022-11-28 15:12:42  Complete
# 9247         9295 2022-11-28 18:40:27 2022-11-28 18:53:50  Complete
#
#       Contact ID  Legacy Comments  Comments Language  \
# 0            NaN              NaN       NaN    Hindi
# ...

# %%
df.drop_duplicates(subset=['Student ID\n (ePunjab ID)'])
# Out:
#       Response ID        Time Started      Date Submitted    Status  \
# 0              46 2022-11-04 07:03:28 2022-11-04 07:07:04  Complete
# 416           462 2022-11-04 23:42:25 2022-11-04 23:49:06  Complete
# 417           463 2022-11-05 00:03:18 2022-11-05 00:16:09  Complete
# 418           464 2022-11-05 00:16:57 2022-11-05 00:20:19  Complete
# 419           465 2022-11-05 00:27:55 2022-11-05 00:32:36  Complete
# ...           ...                 ...                 ...       ...
# 9236         9284 2022-11-28 04:27:36 2022-11-28 04:38:09  Complete
# 9239         9287 2022-11-28 08:54:00 2022-11-28 08:57:34   Partial
# 9243         9291 2022-11-28 13:48:48 2022-11-28 13:50:43   Partial
# 9245         9293 2022-11-28 14:43:04 2022-11-28 14:45:36  Complete
# 9247         9295 2022-11-28 18:40:27 2022-11-28 18:53:50  Complete
#
#       Contact ID  Legacy Comments  Comments Language  \
# 0            NaN              NaN       NaN    Hindi
# ...

# %%
df.columns
# Out:
# Index(['Response ID', 'Time Started', 'Date Submitted', 'Status', 'Contact ID',
#        'Legacy Comments', 'Comments', 'Language', 'Referer', 'SessionID',
#        'User Agent', 'Tags', 'IP Address', 'Longitude', 'Latitude', 'Country',
#        'City', 'State/Region', 'Postal', 'New Hidden Value', 'name',
#        'dob_year', 'dob_month', 'dob_date', 'hh_size', 'mother_education',
#        'father_education', 'personal_phone', 'Student ID\n (ePunjab ID)',
#        'demographic_duration', '1a_grit_localtravel', '1b_grit_localtravel',
#        '2a_grit_errands', '2b_grit_errands', '3a_grit_publicspeaking',
#        '3b_grit_publicspeaking', '4a_grit_discussion', '4b_grit_discussion',
#        '5a_grit_persevered', '5b_grit_persevered', '6a_tnt_extraleadership',
#        '6b_tnt_extraleadership', '7a_tnt_newskill', '7b_tnt_newskill',
#        '8a_tnt_helpingothers', '8b_tnt_helpingothers', '9a_tnt_risktaking',
#        '9b_tnt_risktaking', '10a_tnt_project', '10a_tnt_project_example',
# ...

# %%
myvar.duplicated("Student ID\n (ePunjab ID)")
# Out:
# 9248

# %%
dups = df.pivot_table(index = ['Student ID\n (ePunjab ID)'], aggfunc ='size')

# %%
dups
# Out:
# Student ID\n (ePunjab ID)
# 0                      2
# 2                      1
# 4                      1
# 6                      3
# 7                      4
# 58                     1
# 77                     1
# 92                     1
# 352                    1
# 421                    1
# 510                    1
# 666                    1
# 12757                  1
# 13450                  1
# 15533                  2
# 15650                  2
# 16982                  2
# 30689                  2
# 30847                  1
# 30963                  3
# 31201                  1
# 31597                  1
# 33611                  1
# 34320                  1
# 123456                 1
# 147001                 1
# 263868                 1
# 303544                 1
# 323203                 1
# 323652                 1
# 332966                 1
# 336789                 1
# 439703                 2
# 441122                 1
# 458973                 1
# 466461                 1
# ...

# %%
df1 = pd.read_excel("CHANDAN_MARch Punjab BB_Raw Baseline Export_12Dec2022.xlsx",  sheet_name=3)

# %%
df1.head()
# Out:
#    Student ID\n (ePunjab ID)       Student Name  Gender  Class Section  \
# 0                    1992014        SIMRAN KAUR  Female     12       F
# 1                    2270370       SACHIN KUMAR    Male     12       N
# 2                    2351011  SIMRAN DEEP SINGH    Male     12       H
# 3                    2614447    PALVINDER SINGH    Male     11       C
# 4                    2614551             SHIVAM    Male     11       E
#
#        Stream  UDISE Code                                        School Name  \
# 0  Vocational  3090508902                                       GMSSS P.A.U.
# 1    Commerce  3090508902                                       GMSSS P.A.U.
# 2  Vocational  3090508902                                       GMSSS P.A.U.
# 3        Arts  3040111410  FREEDOM FIGHTER SH. AJIT SAINI GMSSS CO-ED LAD...
# 4    Commerce  3040111410  FREEDOM FIGHTER SH. AJIT SAINI GMSSS CO-ED LAD...
#
#     School Id
# 0  3090508902
# 1  3090508902
# 2  3090508902
# ...

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
pd.pandas.set_option('display.max_rows', None)

# %%
df_merge = pd.merge(df, df1, on='Student ID\n (ePunjab ID)')

# %%
df_merge.to_excel("March_baseline_merged_by_gender.xlsx")

# %%
df_merge
# Out:
#       Response ID        Time Started      Date Submitted    Status  \
# 0             462 2022-11-04 23:42:25 2022-11-04 23:49:06  Complete
# 1            7399 2022-11-14 17:06:04 2022-11-14 17:10:23  Complete
# 2             463 2022-11-05 00:03:18 2022-11-05 00:16:09  Complete
# 3            4049 2022-11-09 19:40:29 2022-11-09 19:41:33   Partial
# 4            6413 2022-11-11 19:06:22 2022-11-11 19:07:45  Complete
# ...           ...                 ...                 ...       ...
# 6214         9284 2022-11-28 04:27:36 2022-11-28 04:38:09  Complete
# 6215         9291 2022-11-28 13:48:48 2022-11-28 13:50:43   Partial
# 6216         9292 2022-11-28 13:57:28 2022-11-28 14:01:56  Complete
# 6217         9293 2022-11-28 14:43:04 2022-11-28 14:45:36  Complete
# 6218         9295 2022-11-28 18:40:27 2022-11-28 18:53:50  Complete
#
#       Contact ID  Legacy Comments  Comments Language  \
# 0            NaN              NaN       NaN    Hindi
# ...

# %%
df3 = pd.read_excel("book1_merged_march.xlsx")

# %%
df3
# Out:
#       Response ID        Time Started      Date Submitted    Status Language  \
# 0             462 2022-11-04 23:42:25 2022-11-04 23:49:06  Complete    Hindi
# 1            7399 2022-11-14 17:06:04 2022-11-14 17:10:23  Complete    Hindi
# 2             463 2022-11-05 00:03:18 2022-11-05 00:16:09  Complete    Hindi
# 3            6413 2022-11-11 19:06:22 2022-11-11 19:07:45  Complete    Hindi
# 4             464 2022-11-05 00:16:57 2022-11-05 00:20:19  Complete    Hindi
# ...           ...                 ...                 ...       ...      ...
# 5101         9274 2022-11-27 18:45:27 2022-11-27 18:50:56  Complete    Hindi
# 5102         9284 2022-11-28 04:27:36 2022-11-28 04:38:09  Complete    Hindi
# 5103         9292 2022-11-28 13:57:28 2022-11-28 14:01:56  Complete    Hindi
# 5104         9293 2022-11-28 14:43:04 2022-11-28 14:45:36  Complete    Hindi
# 5105         9295 2022-11-28 18:40:27 2022-11-28 18:53:50  Complete    Hindi
#
# ...

# %%
result_df = df3.drop_duplicates(keep='first')

# %%
myvar = pd.DataFrame(result_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8360\3716752222.py in <module>
# ----> 1 myvar = pd.DataFrame(result_df)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     754         else:
#     755             if index is None or columns is None:
# --> 756                 raise ValueError("DataFrame constructor not properly called!")
#     757
#     758             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
duplicate = df3[df3.duplicated("Student ID\n (ePunjab ID)")]

# %%
duplicate
# Out:
#       Response ID        Time Started      Date Submitted    Status Language  \
# 1            7399 2022-11-14 17:06:04 2022-11-14 17:10:23  Complete    Hindi
# 3            6413 2022-11-11 19:06:22 2022-11-11 19:07:45  Complete    Hindi
# 6            3737 2022-11-09 18:11:02 2022-11-09 18:12:56  Complete    Hindi
# 8            4704 2022-11-10 14:02:01 2022-11-10 14:06:23  Complete    Hindi
# 9            4747 2022-11-10 14:40:59 2022-11-10 14:43:16  Complete    Hindi
# ...           ...                 ...                 ...       ...      ...
# 5052         9063 2022-11-24 17:41:22 2022-11-24 17:43:49  Complete    Hindi
# 5071         9244 2022-11-26 11:31:03 2022-11-26 11:35:47  Complete    Hindi
# 5081         9181 2022-11-25 15:59:24 2022-11-25 16:04:07  Complete    Hindi
# 5090         9248 2022-11-26 13:38:14 2022-11-26 13:45:12  Complete    Hindi
# 5091         9249 2022-11-26 13:46:19 2022-11-26 13:50:58  Complete    Hindi
#
# ...

# %%
result_df = drop_duplicates

# %%
result_df
# Out:
# <bound method DataFrame.drop_duplicates of       Response ID        Time Started      Date Submitted    Status Language  \
# 0             462 2022-11-04 23:42:25 2022-11-04 23:49:06  Complete    Hindi
# 1            7399 2022-11-14 17:06:04 2022-11-14 17:10:23  Complete    Hindi
# 2             463 2022-11-05 00:03:18 2022-11-05 00:16:09  Complete    Hindi
# 3            6413 2022-11-11 19:06:22 2022-11-11 19:07:45  Complete    Hindi
# 4             464 2022-11-05 00:16:57 2022-11-05 00:20:19  Complete    Hindi
# ...           ...                 ...                 ...       ...      ...
# 5101         9274 2022-11-27 18:45:27 2022-11-27 18:50:56  Complete    Hindi
# 5102         9284 2022-11-28 04:27:36 2022-11-28 04:38:09  Complete    Hindi
# 5103         9292 2022-11-28 13:57:28 2022-11-28 14:01:56  Complete    Hindi
# 5104         9293 2022-11-28 14:43:04 2022-11-28 14:45:36  Complete    Hindi
# 5105         9295 2022-11-28 18:40:27 2022-11-28 18:53:50  Complete    Hindi
#
# ...

# %%
pd.duplicate.drop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8360\1363847842.py in <module>
# ----> 1 pd.duplicate.drop()
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'duplicate'

# %%
result
# Out:
# <bound method DataFrame.drop of       Response ID        Time Started      Date Submitted    Status Language  \
# 1            7399 2022-11-14 17:06:04 2022-11-14 17:10:23  Complete    Hindi
# 3            6413 2022-11-11 19:06:22 2022-11-11 19:07:45  Complete    Hindi
# 6            3737 2022-11-09 18:11:02 2022-11-09 18:12:56  Complete    Hindi
# 8            4704 2022-11-10 14:02:01 2022-11-10 14:06:23  Complete    Hindi
# 9            4747 2022-11-10 14:40:59 2022-11-10 14:43:16  Complete    Hindi
# ...           ...                 ...                 ...       ...      ...
# 5052         9063 2022-11-24 17:41:22 2022-11-24 17:43:49  Complete    Hindi
# 5071         9244 2022-11-26 11:31:03 2022-11-26 11:35:47  Complete    Hindi
# 5081         9181 2022-11-25 15:59:24 2022-11-25 16:04:07  Complete    Hindi
# 5090         9248 2022-11-26 13:38:14 2022-11-26 13:45:12  Complete    Hindi
# 5091         9249 2022-11-26 13:46:19 2022-11-26 13:50:58  Complete    Hindi
#
# ...

# %%
var = df3.drop_duplicates(subset= 'Student ID\n (ePunjab ID)', keep = 'first')

# %%
var
# Out:
#       Response ID        Time Started      Date Submitted    Status Language  \
# 0             462 2022-11-04 23:42:25 2022-11-04 23:49:06  Complete    Hindi
# 2             463 2022-11-05 00:03:18 2022-11-05 00:16:09  Complete    Hindi
# 4             464 2022-11-05 00:16:57 2022-11-05 00:20:19  Complete    Hindi
# 5             465 2022-11-05 00:27:55 2022-11-05 00:32:36  Complete    Hindi
# 7             466 2022-11-05 04:23:57 2022-11-05 04:33:33  Complete    Hindi
# ...           ...                 ...                 ...       ...      ...
# 5101         9274 2022-11-27 18:45:27 2022-11-27 18:50:56  Complete    Hindi
# 5102         9284 2022-11-28 04:27:36 2022-11-28 04:38:09  Complete    Hindi
# 5103         9292 2022-11-28 13:57:28 2022-11-28 14:01:56  Complete    Hindi
# 5104         9293 2022-11-28 14:43:04 2022-11-28 14:45:36  Complete    Hindi
# 5105         9295 2022-11-28 18:40:27 2022-11-28 18:53:50  Complete    Hindi
#
# ...

# %%
var.isnull()
# Out:
#       Response ID  Time Started  Date Submitted  Status  Language  Longitude  \
# 0           False         False           False   False     False      False
# 2           False         False           False   False     False      False
# 4           False         False           False   False     False      False
# 5           False         False           False   False     False      False
# 7           False         False           False   False     False      False
# ...           ...           ...             ...     ...       ...        ...
# 5101        False         False           False   False     False      False
# 5102        False         False           False   False     False      False
# 5103        False         False           False   False     False      False
# 5104        False         False           False   False     False      False
# 5105        False         False           False   False     False      False
#
# ...

# %%
var.to_excel("March_baseline_final.xlsx")

# %%
var.isnull().sum()
# Out:
# Response ID                     0
# Time Started                    0
# Date Submitted                  0
# Status                          0
# Language                        0
# Longitude                       7
# Latitude                        7
# Country                         7
# City                          352
# State/Region                  333
# Postal                        355
# New Hidden Value                0
# name                            0
# dob_year                        2
# dob_month                       2
# dob_date                        2
# hh_size                         0
# mother_education                0
# father_education                0
# personal_phone                  0
# Student ID\n (ePunjab ID)       0
# 1a_grit_localtravel             0
# 1b_grit_localtravel          3201
# 2a_grit_errands                 0
# 2b_grit_errands              3806
# 3a_grit_publicspeaking          0
# 3b_grit_publicspeaking       2603
# ...

# %%
dataset = pd.read_excel("March_baseline_final - Copy.xlsx",  sheet_name="Sheet1")

# %%
dataset
# Out:
#       ResponseID  StudentID\n(ePunjabID) Language Country      City  \
# 0            462                 5217774    Hindi   India  Ludhiana
# 1            463                12215275    Hindi   India  Ludhiana
# 2            464                 4680164    Hindi   India  Ludhiana
# 3            465                 5510956    Hindi   India       NaN
# 4            466                11761609    Hindi   India  Ludhiana
# ...          ...                     ...      ...     ...       ...
# 4059        9274                 3312529    Hindi   India  Ludhiana
# 4060        9284                13620228    Hindi   India  Ludhiana
# 4061        9292                 9249664    Hindi   India    Mohali
# 4062        9293                 3284667    Hindi   India       NaN
# 4063        9295                 5544026    Hindi   India  Ludhiana
#
#       State/Region    Postal  dob_year  dob_month  dob_date  ...  \
# 0             23.0  141015.0    2007.0    January      23.0  ...
# ...

# %%
dataset_modified = dataset.copy()
dataset_modified
# Out:
#       ResponseID  StudentID\n(ePunjabID) Language Country      City  \
# 0            462                 5217774    Hindi   India  Ludhiana
# 1            463                12215275    Hindi   India  Ludhiana
# 2            464                 4680164    Hindi   India  Ludhiana
# 3            465                 5510956    Hindi   India       NaN
# 4            466                11761609    Hindi   India  Ludhiana
# ...          ...                     ...      ...     ...       ...
# 4059        9274                 3312529    Hindi   India  Ludhiana
# 4060        9284                13620228    Hindi   India  Ludhiana
# 4061        9292                 9249664    Hindi   India    Mohali
# 4062        9293                 3284667    Hindi   India       NaN
# 4063        9295                 5544026    Hindi   India  Ludhiana
#
#       State/Region    Postal  dob_year  dob_month  dob_date  ...  \
# 0             23.0  141015.0    2007.0    January      23.0  ...
# ...

# %%
dataset_modified.columns
# Out:
# Index(['ResponseID', 'StudentID\n(ePunjabID)', 'Language', 'Country', 'City',
#        'State/Region', 'Postal', 'dob_year', 'dob_month', 'dob_date', 'Class',
#        'Section', 'hh_size', 'mother_education', 'father_education', 'Stream',
#        'personal_phone', 'Gender', '1a_grit_localtravel',
#        '1b_grit_localtravel', '2a_grit_errands', '2b_grit_errands',
#        '3a_grit_publicspeaking', '3b_grit_publicspeaking',
#        '4a_grit_discussion', '4b_grit_discussion', '5a_grit_persevered',
#        '5b_grit_persevered', '6a_tnt_extraleadership',
#        '6b_tnt_extraleadership', '7a_tnt_newskill', '7b_tnt_newskill',
#        '8a_tnt_helpingothers', '8b_tnt_helpingothers', '9a_tnt_risktaking',
#        '9b_tnt_risktaking', '10a_tnt_project', '10a_tnt_project_example',
#        '10b_tnt_project', '11a_sa_feedback', '11b_sa_feedback',
#        '12a_sa_helpseeking', '12b_sa_helpseeking', '13a_sa_values',
#        '13b_sa_values', '14a_sa_emotions', '14b_sa_emotions',
# ...

# %%
id_vars = list(dataset_modified.columns)[ : 18]
value_vars = list(dataset_modified.columns)[18 : ]

# %%
id_vars
# Out:
# ['ResponseID',
#  'StudentID\n(ePunjabID)',
#  'Language',
#  'Country',
#  'City',
#  'State/Region',
#  'Postal',
#  'dob_year',
#  'dob_month',
#  'dob_date',
#  'Class',
#  'Section',
#  'hh_size',
#  'mother_education',
#  'father_education',
#  'Stream',
#  'personal_phone',
#  'Gender']

# %%
dataset_melted.Question
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10796\844230890.py in <module>
# ----> 1 dataset_melted.Question
#
# NameError: name 'dataset_melted' is not defined

# %%
dataset_melted = dataset_modified.melt(id_vars=id_vars, value_vars = value_vars, var_name="Question", value_name="Answer")
dataset_melted
# Out:
#         ResponseID  StudentID\n(ePunjabID) Language Country      City  \
# 0              462                 5217774    Hindi   India  Ludhiana
# 1              463                12215275    Hindi   India  Ludhiana
# 2              464                 4680164    Hindi   India  Ludhiana
# 3              465                 5510956    Hindi   India       NaN
# 4              466                11761609    Hindi   India  Ludhiana
# ...            ...                     ...      ...     ...       ...
# 166619        9274                 3312529    Hindi   India  Ludhiana
# 166620        9284                13620228    Hindi   India  Ludhiana
# 166621        9292                 9249664    Hindi   India    Mohali
# 166622        9293                 3284667    Hindi   India       NaN
# 166623        9295                 5544026    Hindi   India  Ludhiana
#
#         State/Region    Postal  dob_year  dob_month  dob_date  Class Section  \
# ...

# %%
#its in a funky format so we use resetindex
respondents = dataset_melted[dataset_melted["Answer"].notna()]
respondents = respondents.groupby("Question")["ResponseID"].nunique().reset_index()
respondents.rename(columns={"ResponseID":"Respondents"}, inplace=True)
respondents
# Out:
#                     Question  Respondents
# 0            10a_tnt_project         4064
# 1    10a_tnt_project_example          941
# 2            10b_tnt_project         3121
# 3            11a_sa_feedback         4064
# 4            11b_sa_feedback          633
# 5         12a_sa_helpseeking         4062
# 6         12b_sa_helpseeking          356
# 7              13a_sa_values         4062
# 8              13b_sa_values          410
# 9            14a_sa_emotions         4062
# 10           14b_sa_emotions          533
# 11          15a_sa_influence         4062
# 12          15b_sa_influence          685
# 13  16a_ind_doingthingsalone         4062
# 14   16b_sa_doingthingsalone          310
# 15       17a_ind_againstnorm         4058
# 16       17b_ind_againstnorm          897
# 17        18a_ind_reflection         4056
# 18        18b_ind_reflection         1105
# 19       19a_ind_questioning         4056
# 20       19b_ind_questioning          752
# ...

# %%
dataset_merged = pd.merge(left=dataset_melted, right=respondents, how="left", left_on="Question", right_on="Question")
print("Original Data", len(dataset_melted))
print("Merged Data", len(dataset_merged))
dataset_merged
# Out:
# Original Data 166624
# Merged Data 166624
#         ResponseID  StudentID\n(ePunjabID) Language Country      City  \
# 0              462                 5217774    Hindi   India  Ludhiana
# 1              463                12215275    Hindi   India  Ludhiana
# 2              464                 4680164    Hindi   India  Ludhiana
# 3              465                 5510956    Hindi   India       NaN
# 4              466                11761609    Hindi   India  Ludhiana
# ...            ...                     ...      ...     ...       ...
# 166619        9274                 3312529    Hindi   India  Ludhiana
# 166620        9284                13620228    Hindi   India  Ludhiana
# 166621        9292                 9249664    Hindi   India    Mohali
# 166622        9293                 3284667    Hindi   India       NaN
# 166623        9295                 5544026    Hindi   India  Ludhiana
#
#         State/Region    Postal  dob_year  dob_month  dob_date  ...  Section  \
# ...

# %%
same_answer = dataset_melted ##[dataset_melted["Answer"].notna()]
same_answer = same_answer.groupby(["Question","Answer"])["ResponseID"].nunique().reset_index()
same_answer.rename(columns={"ResponseID":"same_answer"}, inplace=True)
same_answer
# Out:
#                     Question                                        Answer  \
# 0            10a_tnt_project                                        (a)yes
# 1            10a_tnt_project                                         (b)no
# 2    10a_tnt_project_example                                             1
# 3    10a_tnt_project_example                                          1234
# 4    10a_tnt_project_example                                          2000
# ..                       ...                                           ...
# 859        9a_tnt_risktaking                                         (d)no
# 860        9b_tnt_risktaking                               (a)Didnotneedto
# 861        9b_tnt_risktaking                               (b)Didnotwantto
# 862        9b_tnt_risktaking       (c)Wantedto,butdidnothavetheopportunity
# 863        9b_tnt_risktaking  (d)Wasnotallowed(byfamily/caregiver/teacher)
#
#      same_answer
# 0            943
# 1           3121
# ...

# %%
same_answer
# Out:
#                     Question                                        Answer  \
# 0            10a_tnt_project                                        (a)yes
# 1            10a_tnt_project                                         (b)no
# 2    10a_tnt_project_example                                             1
# 3    10a_tnt_project_example                                          1234
# 4    10a_tnt_project_example                                          2000
# ..                       ...                                           ...
# 859        9a_tnt_risktaking                                         (d)no
# 860        9b_tnt_risktaking                               (a)Didnotneedto
# 861        9b_tnt_risktaking                               (b)Didnotwantto
# 862        9b_tnt_risktaking       (c)Wantedto,butdidnothavetheopportunity
# 863        9b_tnt_risktaking  (d)Wasnotallowed(byfamily/caregiver/teacher)
#
#      same_answer
# 0            943
# 1           3121
# ...

# %%
dataset_merged_two = pd.merge(left=dataset_merged, right=same_answer, how="left", left_on=["Question","Answer"], right_on=["Question","Answer"])
dataset_merged_two["same_answer"].fillna(0,inplace= True)
print("Original Data", len(dataset_merged))
print("Merged Data", len(dataset_merged_two))
dataset_merged_two
# Out:
# Original Data 166624
# Merged Data 166624
#         ResponseID  StudentID\n(ePunjabID) Language Country      City  \
# 0              462                 5217774    Hindi   India  Ludhiana
# 1              463                12215275    Hindi   India  Ludhiana
# 2              464                 4680164    Hindi   India  Ludhiana
# 3              465                 5510956    Hindi   India       NaN
# 4              466                11761609    Hindi   India  Ludhiana
# ...            ...                     ...      ...     ...       ...
# 166619        9274                 3312529    Hindi   India  Ludhiana
# 166620        9284                13620228    Hindi   India  Ludhiana
# 166621        9292                 9249664    Hindi   India    Mohali
# 166622        9293                 3284667    Hindi   India       NaN
# 166623        9295                 5544026    Hindi   India  Ludhiana
#
#         State/Region    Postal  dob_year  dob_month  dob_date  ...  hh_size  \
# ...

# %%
output = dataset_merged_two.copy()
output
# Out:
#         ResponseID  StudentID\n(ePunjabID) Language Country      City  \
# 0              462                 5217774    Hindi   India  Ludhiana
# 1              463                12215275    Hindi   India  Ludhiana
# 2              464                 4680164    Hindi   India  Ludhiana
# 3              465                 5510956    Hindi   India       NaN
# 4              466                11761609    Hindi   India  Ludhiana
# ...            ...                     ...      ...     ...       ...
# 166619        9274                 3312529    Hindi   India  Ludhiana
# 166620        9284                13620228    Hindi   India  Ludhiana
# 166621        9292                 9249664    Hindi   India    Mohali
# 166622        9293                 3284667    Hindi   India       NaN
# 166623        9295                 5544026    Hindi   India  Ludhiana
#
#         State/Region    Postal  dob_year  dob_month  dob_date  ...  hh_size  \
# ...

# %%
output.to_csv("Final_outputs.csv")

# %%
##new

# %%
dataset1
# Out:
#         Unnamed: 0  ResponseID  StudentID\n(ePunjabID) Language Country  \
# 0                0         462                 5217774    Hindi   India
# 1                1         463                12215275    Hindi   India
# 2                2         464                 4680164    Hindi   India
# 3                3         465                 5510956    Hindi   India
# 4                4         466                11761609    Hindi   India
# ...            ...         ...                     ...      ...     ...
# 166619      166619        9274                 3312529    Hindi   India
# 166620      166620        9284                13620228    Hindi   India
# 166621      166621        9292                 9249664    Hindi   India
# 166622      166622        9293                 3284667    Hindi   India
# 166623      166623        9295                 5544026    Hindi   India
#
#             City  State/Region    Postal  dob_year  dob_month  ...  hh_size  \
# ...

# %%
df.groupby('name')['activity'].value_counts()
