# %%
import pandas as pd
import os

# %%
dataset1 = pd.read_excel("Final_outputs.xlsx")
dataset1
# Out:
#         Unnamed: 0  ResponseID  StudentID\n(ePunjabID) Language Country  \
# 0                0         462                 5217774    Hindi   India
# 1                1         463                12215275    Hindi   India
# 2                2         464                 4680164    Hindi   India
# 3                3         465                 5510956    Hindi   India
# 4                4         466                11761609    Hindi   India
# ...            ...         ...                     ...      ...     ...
# 166619      166619        9274                 3312529    Hindi   India
# 166620      166620        9284                13620228    Hindi   India
# 166621      166621        9292                 9249664    Hindi   India
# 166622      166622        9293                 3284667    Hindi   India
# 166623      166623        9295                 5544026    Hindi   India
#
#             City  State/Region    Postal  dob_year  dob_month  ...  hh_size  \
# ...

# %%
dataset1
# Out:
#         Unnamed: 0  ResponseID  StudentID\n(ePunjabID) Language Country  \
# 0                0         462                 5217774    Hindi   India
# 1                1         463                12215275    Hindi   India
# 2                2         464                 4680164    Hindi   India
# 3                3         465                 5510956    Hindi   India
# 4                4         466                11761609    Hindi   India
# ...            ...         ...                     ...      ...     ...
# 166619      166619        9274                 3312529    Hindi   India
# 166620      166620        9284                13620228    Hindi   India
# 166621      166621        9292                 9249664    Hindi   India
# 166622      166622        9293                 3284667    Hindi   India
# 166623      166623        9295                 5544026    Hindi   India
#
#             City  State/Region    Postal  dob_year  dob_month  ...  hh_size  \
# ...

# %%
car = dataset1.groupby('Question')['Answer'].value_counts()

# %%
index_names = dataset1[dataset1['Question'] =="10a_tnt_project_example"].index
index_names
# Out:
# Int64Index([77216, 77217, 77218, 77219, 77220, 77221, 77222, 77223, 77224,
#             77225,
#             ...
#             81270, 81271, 81272, 81273, 81274, 81275, 81276, 81277, 81278,
#             81279],
#            dtype='int64', length=4064)

# %%
dataset1.drop(index_names, inplace = True)

# %%
output = dataset1.groupby('Question')['Answer'].value_counts()

# %%
output
# Out:
# Question           Answer
# 10a_tnt_project    (b)no                                           3121
#                    (a)yes                                           943
# 10b_tnt_project    (c)Wantedto,butdidnothavetheopportunity         1504
#                    (a)Didnotneedto                                  895
#                    (b)Didnotwantto                                  432
#                                                                    ...
# 9a_tnt_risktaking  (d)no                                            720
# 9b_tnt_risktaking  (a)Didnotneedto                                  366
#                    (b)Didnotwantto                                  185
#                    (c)Wantedto,butdidnothavetheopportunity           95
#                    (d)Wasnotallowed(byfamily/caregiver/teacher)      73
# Name: Answer, Length: 158, dtype: int64

# %%
output.to_csv("qna_based.csv")

# %%
dataset1.Question
# Out:
# 0              1a_grit_localtravel
# 1              1a_grit_localtravel
# 2              1a_grit_localtravel
# 3              1a_grit_localtravel
# 4              1a_grit_localtravel
#                     ...
# 166619    20b_ind_informeddecision
# 166620    20b_ind_informeddecision
# 166621    20b_ind_informeddecision
# 166622    20b_ind_informeddecision
# 166623    20b_ind_informeddecision
# Name: Question, Length: 166624, dtype: object

# %%
df = pd.read_excel("March_baseline_final - Copy.xlsx",  sheet_name=0)
df
# Out:
#       ResponseID  StudentID\n(ePunjabID) Language Country      City  \
# 0            462                 5217774    Hindi   India  Ludhiana
# 1            463                12215275    Hindi   India  Ludhiana
# 2            464                 4680164    Hindi   India  Ludhiana
# 3            465                 5510956    Hindi   India       NaN
# 4            466                11761609    Hindi   India  Ludhiana
# ...          ...                     ...      ...     ...       ...
# 4059        9274                 3312529    Hindi   India  Ludhiana
# 4060        9284                13620228    Hindi   India  Ludhiana
# 4061        9292                 9249664    Hindi   India    Mohali
# 4062        9293                 3284667    Hindi   India       NaN
# 4063        9295                 5544026    Hindi   India  Ludhiana
#
#       State/Region    Postal  dob_year  dob_month  dob_date  ...  \
# 0             23.0  141015.0    2007.0    January      23.0  ...
# ...

# %%
percent= 100*(len(df.loc[:,df.isnull().sum(axis=0)>=1 ].index) / len(df.index))
print(round(percent,2))
# Out:
# 100.0

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df.sort_values('percent_missing', inplace=True)

# %%
percent_missing
# Out:
# ResponseID                   0.000000
# StudentID\n(ePunjabID)       0.000000
# Language                     0.000000
# Country                      0.172244
# City                         8.661417
# State/Region                 8.193898
# Postal                       8.735236
# dob_year                     0.049213
# dob_month                    0.049213
# dob_date                     0.049213
# Class                        0.000000
# Section                      0.000000
# hh_size                      0.000000
# mother_education             0.000000
# father_education             0.000000
# Stream                       0.000000
# personal_phone               0.000000
# Gender                       0.000000
# 1a_grit_localtravel          0.000000
# 1b_grit_localtravel         78.764764
# 2a_grit_errands              0.000000
# 2b_grit_errands             93.651575
# 3a_grit_publicspeaking       0.000000
# 3b_grit_publicspeaking      64.050197
# 4a_grit_discussion           0.000000
# ...

# %%
missing_value_df
# Out:
#                                        column_name  percent_missing
# ResponseID                              ResponseID         0.000000
# 11a_sa_feedback                    11a_sa_feedback         0.000000
# 10a_tnt_project                    10a_tnt_project         0.000000
# 9a_tnt_risktaking                9a_tnt_risktaking         0.000000
# 8a_tnt_helpingothers          8a_tnt_helpingothers         0.000000
# 7a_tnt_newskill                    7a_tnt_newskill         0.000000
# 6a_tnt_extraleadership      6a_tnt_extraleadership         0.000000
# 5a_grit_persevered              5a_grit_persevered         0.000000
# 4a_grit_discussion              4a_grit_discussion         0.000000
# 2a_grit_errands                    2a_grit_errands         0.000000
# 1a_grit_localtravel            1a_grit_localtravel         0.000000
# Gender                                      Gender         0.000000
# personal_phone                      personal_phone         0.000000
# ...

# %%
missing_value_df.to_excel("missing1.xlsx")

# %%
df = pd.read_excel("Rfile_ex.xlsx")
df
# Out:
#       Response_ID        Time_Started      Date_Submitted    Status  \
# 0             462 2022-11-04 23:42:25 2022-11-04 23:49:06  Complete
# 1             463 2022-11-05 00:03:18 2022-11-05 00:16:09  Complete
# 2             464 2022-11-05 00:16:57 2022-11-05 00:20:19  Complete
# 3             465 2022-11-05 00:27:55 2022-11-05 00:32:36  Complete
# 4             466 2022-11-05 04:23:57 2022-11-05 04:33:33  Complete
# ...           ...                 ...                 ...       ...
# 5353         9284 2022-11-28 04:27:36 2022-11-28 04:38:09  Complete
# 5354         9292 2022-11-28 13:57:28 2022-11-28 14:01:56  Complete
# 5355         9293 2022-11-28 14:43:04 2022-11-28 14:45:36  Complete
# 5356         9294 2022-11-28 15:02:49 2022-11-28 15:12:42  Complete
# 5357         9295 2022-11-28 18:40:27 2022-11-28 18:53:50  Complete
#
#       Contact_ID  Legacy_Comments  Comments Language  \
# 0            NaN              NaN       NaN    Hindi
# ...

# %%
df = df.drop_duplicates(subset='Student_ID', keep="first")
df
# Out:
#       Response_ID        Time_Started      Date_Submitted    Status  \
# 0             462 2022-11-04 23:42:25 2022-11-04 23:49:06  Complete
# 1             463 2022-11-05 00:03:18 2022-11-05 00:16:09  Complete
# 2             464 2022-11-05 00:16:57 2022-11-05 00:20:19  Complete
# 3             465 2022-11-05 00:27:55 2022-11-05 00:32:36  Complete
# 4             466 2022-11-05 04:23:57 2022-11-05 04:33:33  Complete
# ...           ...                 ...                 ...       ...
# 5352         9276 2022-11-27 19:16:16 2022-11-27 19:28:42  Complete
# 5353         9284 2022-11-28 04:27:36 2022-11-28 04:38:09  Complete
# 5354         9292 2022-11-28 13:57:28 2022-11-28 14:01:56  Complete
# 5355         9293 2022-11-28 14:43:04 2022-11-28 14:45:36  Complete
# 5357         9295 2022-11-28 18:40:27 2022-11-28 18:53:50  Complete
#
#       Contact_ID  Legacy_Comments  Comments Language  \
# 0            NaN              NaN       NaN    Hindi
# ...

# %%
df.to_excel("duplicate_gon.xlsx")

# %%
df = pd.read_excel("duplicate_gon.xlsx")
df
# Out:
#       Unnamed: 0  Response_ID        Time_Started      Date_Submitted  \
# 0              0          462 2022-11-04 23:42:25 2022-11-04 23:49:06
# 1              1          463 2022-11-05 00:03:18 2022-11-05 00:16:09
# 2              2          464 2022-11-05 00:16:57 2022-11-05 00:20:19
# 3              3          465 2022-11-05 00:27:55 2022-11-05 00:32:36
# 4              4          466 2022-11-05 04:23:57 2022-11-05 04:33:33
# ...          ...          ...                 ...                 ...
# 4288        5352         9276 2022-11-27 19:16:16 2022-11-27 19:28:42
# 4289        5353         9284 2022-11-28 04:27:36 2022-11-28 04:38:09
# 4290        5354         9292 2022-11-28 13:57:28 2022-11-28 14:01:56
# 4291        5355         9293 2022-11-28 14:43:04 2022-11-28 14:45:36
# 4292        5357         9295 2022-11-28 18:40:27 2022-11-28 18:53:50
#
#         Status  Contact_ID  Legacy_Comments  Comments Language  \
# ...

# %%
df1 = pd.read_excel("students_data.xlsx")
df1
# Out:
#        Student_ID       Student Name  Gender  Class Section      Stream  \
# 0         1992014        SIMRAN KAUR  Female     12       F  Vocational
# 1         2270370       SACHIN KUMAR    Male     12       N    Commerce
# 2         2351011  SIMRAN DEEP SINGH    Male     12       H  Vocational
# 3         2614447    PALVINDER SINGH    Male     11       C        Arts
# 4         2614551             SHIVAM    Male     11       E    Commerce
# ...           ...                ...     ...    ...     ...         ...
# 21493    13038034    KHUSHDEEP SINGH    Male     11       D     Science
# 21494    13581085     DEEPINDER KAUR  Female     11       A     Science
# 21495    13615613  BARINDERDEEP KAUR  Female     11       B     Science
# 21496    13700533               EKTA  Female     11       B     Science
# 21497    11111111      DUMMY STUDENT  Female     11       Z        Arts
#
#        UDISE Code                                        School Name  \
# ...

# %%
df_merge = pd.merge(df, df1, on='Student_ID')

# %%
df_merge
# Out:
#       Unnamed: 0  Response_ID        Time_Started      Date_Submitted  \
# 0              0          462 2022-11-04 23:42:25 2022-11-04 23:49:06
# 1              1          463 2022-11-05 00:03:18 2022-11-05 00:16:09
# 2              2          464 2022-11-05 00:16:57 2022-11-05 00:20:19
# 3              3          465 2022-11-05 00:27:55 2022-11-05 00:32:36
# 4              4          466 2022-11-05 04:23:57 2022-11-05 04:33:33
# ...          ...          ...                 ...                 ...
# 4059        5350         9274 2022-11-27 18:45:27 2022-11-27 18:50:56
# 4060        5353         9284 2022-11-28 04:27:36 2022-11-28 04:38:09
# 4061        5354         9292 2022-11-28 13:57:28 2022-11-28 14:01:56
# 4062        5355         9293 2022-11-28 14:43:04 2022-11-28 14:45:36
# 4063        5357         9295 2022-11-28 18:40:27 2022-11-28 18:53:50
#
#         Status  Contact_ID  Legacy_Comments  Comments Language  \
# ...

# %%
df_merge.to_excel("merged.xlsx")

# %%
df_merge.describe()
# Out:
#         Unnamed: 0  Response_ID  Contact_ID  Legacy_Comments  Comments  Tags  \
# count  4064.000000  4064.000000         0.0              0.0       0.0   0.0
# mean   2449.851870  4368.729085         NaN              NaN       NaN   NaN
# std    1512.729922  2471.685487         NaN              NaN       NaN   NaN
# min       0.000000   462.000000         NaN              NaN       NaN   NaN
# 25%    1118.500000  2178.750000         NaN              NaN       NaN   NaN
# 50%    2386.500000  4259.500000         NaN              NaN       NaN   NaN
# 75%    3684.500000  6320.000000         NaN              NaN       NaN   NaN
# max    5357.000000  9295.000000         NaN              NaN       NaN   NaN
#
#          Longitude     Latitude         Postal     dob_year     dob_date  \
# count  4057.000000  4057.000000    3709.000000  4062.000000  4062.000000
# mean     76.485645    29.434644  173835.702076  2005.779419    15.263909
# ...

# %%
df.columns
# Out:
# Index(['Response_ID', 'Time_Started', 'Date_Submitted', 'Status', 'Contact_ID',
#        'Legacy_Comments', 'Comments', 'Language', 'Referer', 'SessionID',
#        'User_Agent', 'Tags', 'IP_Address', 'Longitude', 'Latitude', 'Country',
#        'City', 'State/Region', 'Postal', 'New_Hidden_Value', 'name',
#        'dob_year', 'dob_month', 'dob_date', 'hh_size', 'mother_education',
#        'father_education', 'personal_phone', 'Student_ID',
#        'demographic_duration', '1a_grit_localtravel', '1b_grit_localtravel',
#        '2a_grit_errands', '2b_grit_errands', '3a_grit_publicspeaking',
#        '3b_grit_publicspeaking', '4a_grit_discussion', '4b_grit_discussion',
#        '5a_grit_persevered', '5b_grit_persevered', '6a_tnt_extraleadership',
#        '6b_tnt_extraleadership', '7a_tnt_newskill', '7b_tnt_newskill',
#        '8a_tnt_helpingothers', '8b_tnt_helpingothers', '9a_tnt_risktaking',
#        '9b_tnt_risktaking', '10a_tnt_project', '10a_tnt_project_example',
# ...
